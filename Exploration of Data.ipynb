# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
df = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %% [markdown]
# # Relationship Between MonthlyIncome & Age

# %% [markdown]
# ### Question : Does age play a role higher monthly income

# %%
age_income_correlation = df[['Age', 'MonthlyIncome']].corr().iloc[0, 1]
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Age', y='MonthlyIncome')
plt.title(f'Correlation between Age and Monthly Income: {age_income_correlation:.2f}')
plt.xlabel('Age')
plt.ylabel('Monthly Income')
plt.grid(True)
plt.show()

# %% [markdown]
# ###### Explanation : The Pearson correlation coefficient between Age and Monthly Income in the dataset is approximately 0.50. This indicates a moderate positive linear relationship, suggesting that as Age increases, Monthly Income tends to increase as well, but not perfectly.

# %% [markdown]
# #### Correlation Age - Years Of Experience - Monthly Income

# %% [markdown]
# #### Which one is most important to monthly income

# %%
# Use pearson correlation
correlation_age_income = df[['Age', 'MonthlyIncome']].corr().iloc[0, 1]
correlation_yearsatcompany_income = df[['YearsAtCompany', 'MonthlyIncome']].corr().iloc[0, 1]
correlation_age_income, correlation_yearsatcompany_income
# Out:
# (0.4978545669265801, 0.5142848257331957)

# %% [markdown]
# #####  Explanation :YearsAtCompany play a more important role than Age in the income
